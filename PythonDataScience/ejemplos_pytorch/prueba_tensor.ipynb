# %%
import torch
zeros_tensor = torch.zeros(3)
print(zeros_tensor)  # tensor([0., 0., 0.])

zeros_matrix = torch.zeros((2, 3))
print(zeros_matrix)
# Out:
# tensor([0., 0., 0.])
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
import torch

# %%
torch.__version__
# Out:
# '2.10.0'
