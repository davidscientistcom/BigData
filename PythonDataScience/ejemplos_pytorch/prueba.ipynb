# %%
pip install torch torchvision
# Out:
# Collecting torch
#   Downloading torch-2.10.0-cp313-none-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading torchvision-0.25.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (5.4 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/testPrueba2/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/testPrueba2/lib/python3.13/site-packages (from torch) (80.9.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/testPrueba2/lib/python3.13/site-packages (from torchvision) (2.3.4)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-12.1.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Downloading torch-2.10.0-cp313-none-macosx_11_0_arm64.whl (79.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 2.7 MB/s  0:00:29m0:00:0100:01
# Downloading torchvision-0.25.0-cp313-cp313-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.3 MB/s  0:00:00 eta 0:00:01
# Downloading fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.0 MB/s  0:00:00 eta 0:00:01
# Downloading pillow-12.1.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.0 MB/s  0:00:01 eta 0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 3.7 MB/s  0:00:01 eta 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 5.2 MB/s  0:00:00
# Downloading filelock-3.20.3-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl (12 kB)
# Installing collected packages: mpmath, sympy, pillow, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [torchvision] [torchvision]
# Successfully installed MarkupSafe-3.0.3 filelock-3.20.3 fsspec-2026.1.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 pillow-12.1.0 sympy-1.14.0 torch-2.10.0 torchvision-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
tensor = torch.tensor([1, 2, 3])
print(tensor)  # tensor([1, 2, 3])

tensor_multi = torch.tensor([[1, 2], [3, 4]])
print(tensor_multi)
# Out:
# tensor([1, 2, 3])
# tensor([[1, 2],
#         [3, 4]])

# %%
tensor.shape, tensor.dtype, tensor.device
# Out:
# (torch.Size([3]), torch.int64, device(type='cpu'))
